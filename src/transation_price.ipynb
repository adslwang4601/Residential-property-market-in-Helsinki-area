# %%
import json
import pandas as pd

import json

# %%
pd.read_json('./price_spider/price_spider/spiders/price.jl', lines=True,orient='records').drop_duplicates().tail(100)
# Out:
#                       district      apartment_type property_type floor_area  \
# 1594                    Kaitaa    6h, avokeitti...            rt     114,00
# 1595                   Tapiola      4 h, k, työ...            rt     165,00
# 1596           Pohjois-tapiola              4h,k,s            rt      92,50
# 1597                 Tuomarila  4h+k+kph+s+eril...            rt      96,00
# 1598                Laajalahti            3-4h+k+s            rt     100,00
# ...                        ...                 ...           ...        ...
# 1696  \n\t\t\t\t\t\t\t\t\t\t\t                  35                     None
# 1698  \n\t\t\t\t\t\t\t\t\t\t\t                  36                     None
# 1700  \n\t\t\t\t\t\t\t\t\t\t\t                  37                     None
# 1702  \n\t\t\t\t\t\t\t\t\t\t\t                  38                     None
# 1704  \n\t\t\t\t\t\t\t\t\t\t\t                  39                     None
#
# ...

# %%
df = pd.read_csv('../data/Espoo_Vantaa.csv')

# %%
start_urls = [

    f"https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps={postcode}&renderType=renderTypeTable" \
    for postcode in postcode_list
]

# %%
start_urls
# Out:
# ['https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02330&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02920&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02320&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02600&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02710&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02210&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02740&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02360&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02760&renderType=renderTypeTable',
#  'https://asuntojen.hintatiedot.fi/haku/vuokratiedot?c=&ps=02650&renderType=renderTypeTable',
# ...
